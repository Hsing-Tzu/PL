# %%
import json

# %%
job = open('jobsatisfication.json',encoding="utf8")
data = json.load(job)
type(data)
# Out:
# dict

# %%
data.items()
# Out:
# dict_items([('滿意度調查', {'性別': {'男': {'樣本數（人）': '2043', '很滿意（%）': '25.3', '滿意（%）': '49.1', '普通（%）': '22.9', '不滿意（%）': '2.2', '很不滿意（%）': '0.5'}, '女': {'樣本數（人）': '2087', '很滿意（%）': '22.2', '滿意（%）': '48.7', '普通（%）': '26.9', '不滿意（%）': '2', '很不滿意（%）': '0.3'}}, '年齡': {'15~24歲': {'樣本數（人）': '272', '很滿意（%）': '37.9', '滿意（%）': '42.2', '普通（%）': '19.5', '不滿意（%）': '0.4', '很不滿意（%）': '-'}, '25~44歲': {'樣本數（人）': '2280', '很滿意（%）': '23.5', '滿意（%）': '46.2', '普通（%）': '27.2', '不滿意（%）': '2.7', '很不滿意（%）': '0.4'}, '25~34歲': {'樣本數（人）': '1083', '很滿意（%）': '24.1', '滿意（%）': '43.3', '普通（%）': '29.3', '不滿意（%）': '3.3', '很不滿意（%）': '0.1'}, '35~44歲': {'樣本數（人）': '1197', '很滿意（%）': '23', '滿意（%）': '48.9', '普通（%）': '25.4', '不滿意（%）': '2.2', '很不滿意（%）': '0.6'}, '45~64歲': {'樣本數（人）': '1480', '很滿意（%）': '21.6', '滿意（%）': '53.6', '普通（%）': '22.7', '不滿意（%）': '1.5', '很不滿意（%）': '0.6'}, '45~54歲': {'樣本數（人）': '899', '很滿意（%）': '22.3', '滿意（%）': '51.5', '普通（%）': '23.9', '不滿意（%）': '1.7', '很不滿意（%）': '0.6'}, '55~64歲': {'樣本數（人）': '581', '很滿意（%）': '20.
# ...

# %%
temp = data.get('滿意度調查')
temp
# Out:
# {'性別': {'男': {'樣本數（人）': '2043',
#    '很滿意（%）': '25.3',
#    '滿意（%）': '49.1',
#    '普通（%）': '22.9',
#    '不滿意（%）': '2.2',
#    '很不滿意（%）': '0.5'},
#   '女': {'樣本數（人）': '2087',
#    '很滿意（%）': '22.2',
#    '滿意（%）': '48.7',
#    '普通（%）': '26.9',
#    '不滿意（%）': '2',
#    '很不滿意（%）': '0.3'}},
#  '年齡': {'15~24歲': {'樣本數（人）': '272',
#    '很滿意（%）': '37.9',
#    '滿意（%）': '42.2',
#    '普通（%）': '19.5',
#    '不滿意（%）': '0.4',
#    '很不滿意（%）': '-'},
#   '25~44歲': {'樣本數（人）': '2280',
#    '很滿意（%）': '23.5',
#    '滿意（%）': '46.2',
#    '普通（%）': '27.2',
#    '不滿意（%）': '2.7',
#    '很不滿意（%）': '0.4'},
#   '25~34歲': {'樣本數（人）': '1083',
#    '很滿意（%）': '24.1',
#    '滿意（%）': '43.3',
#    '普通（%）': '29.3',
#    '不滿意（%）': '3.3',
#    '很不滿意（%）': '0.1'},
#   '35~44歲': {'樣本數（人）': '1197',
#    '很滿意（%）': '23',
#    '滿意（%）': '48.9',
#    '普通（%）': '25.4',
#    '不滿意（%）': '2.2',
#    '很不滿意（%）': '0.6'},
#   '45~64歲': {'樣本數（人）': '1480',
#    '很滿意（%）': '21.6',
#    '滿意（%）': '53.6',
#    '普通（%）': '22.7',
#    '不滿意（%）': '1.5',
# ...

# %%
for n in data.items():
    print(n[0])
# Out:
# 滿意度調查

# %% [markdown]
# ### 定義gender()函數，儲存性別內容

# %%
def gender(dict_categories): 
    number = len(dict_categories['性別']) 
    #len()函式用來計算dict性別共有幾個key
    content = []
    for i in dict_categories['性別']: #for detail in dict_categories['性別'].items:
        detail = (i,dict_categories['性別'][i]) #用 .items 這行就可以不用
        content.append(detail)
    return number, content

# %%
for n in data.items():
    a, b = gender(n[1])
    print(a1)
    print(b1)
# Out:
# 2
# [('男', {'樣本數（人）': '2043', '很滿意（%）': '25.3', '滿意（%）': '49.1', '普通（%）': '22.9', '不滿意（%）': '2.2', '很不滿意（%）': '0.5'}), ('女', {'樣本數（人）': '2087', '很滿意（%）': '22.2', '滿意（%）': '48.7', '普通（%）': '26.9', '不滿意（%）': '2', '很不滿意（%）': '0.3'})]

# %% [markdown]
# ### 定義age()函數，儲存年齡內容

# %%
def age(dict_categories): 
    number = len(dict_categories['年齡']) 
    #len()函式用來計算dict年齡共有幾個key
    content = []
    for i in dict_categories['年齡']: #for detail in dict_categories['年齡'].items:
        detail = (i,dict_categories['年齡'][i]) #用 .items 這行就可以不用
        content.append(detail)
    return number, content

# %%
for n in data.items():
    a, b = age(n[1])
    print(a)
    print(b)
# Out:
# 8
# [('15~24歲', {'樣本數（人）': '272', '很滿意（%）': '37.9', '滿意（%）': '42.2', '普通（%）': '19.5', '不滿意（%）': '0.4', '很不滿意（%）': '-'}), ('25~44歲', {'樣本數（人）': '2280', '很滿意（%）': '23.5', '滿意（%）': '46.2', '普通（%）': '27.2', '不滿意（%）': '2.7', '很不滿意（%）': '0.4'}), ('25~34歲', {'樣本數（人）': '1083', '很滿意（%）': '24.1', '滿意（%）': '43.3', '普通（%）': '29.3', '不滿意（%）': '3.3', '很不滿意（%）': '0.1'}), ('35~44歲', {'樣本數（人）': '1197', '很滿意（%）': '23', '滿意（%）': '48.9', '普通（%）': '25.4', '不滿意（%）': '2.2', '很不滿意（%）': '0.6'}), ('45~64歲', {'樣本數（人）': '1480', '很滿意（%）': '21.6', '滿意（%）': '53.6', '普通（%）': '22.7', '不滿意（%）': '1.5', '很不滿意（%）': '0.6'}), ('45~54歲', {'樣本數（人）': '899', '很滿意（%）': '22.3', '滿意（%）': '51.5', '普通（%）': '23.9', '不滿意（%）': '1.7', '很不滿意（%）': '0.6'}), ('55~64歲', {'樣本數（人）': '581', '很滿意（%）': '20.3', '滿意（%）': '57.2', '普通（%）': '20.8', '不滿意（%）': '1.3', '很不滿意（%）': '0.5'}), ('65歲以上', {'樣本數（人）': '98', '很滿意（%）': '16.4', '滿意（%）': '64', '普通（%）': '19.5', '不滿意（%）': '-', '很不滿意（%）': '-'})]

# %% [markdown]
# ### 定義education()函數，儲存教育程度內容

# %%
def education(dict_categories): 
    number = len(dict_categories['教育程度']) 
    #len()函式用來計算dict教育程度共有幾個key
    content = []
    for i in dict_categories['教育程度']: #for detail in dict_name['教育程度'].items:
        detail = (i,dict_categories['教育程度'][i]) #用 .items 這行就可以不用
        content.append(detail)
    return number, content

# %%
for n in data.items():
    a, b = education(n[1])
    print(a)
    print(b)
# Out:
# 4
# [('國中及以下', {'樣本數（人）': '268', '很滿意（%）': '22.4', '滿意（%）': '55.2', '普通（%）': '21.9', '不滿意（%）': '0.5', '很不滿意（%）': '-'}), ('高中（職）', {'樣本數（人）': '1076', '很滿意（%）': '27.8', '滿意（%）': '45.3', '普通（%）': '24.9', '不滿意（%）': '1.4', '很不滿意（%）': '0.6'}), ('專科及大學', {'樣本數（人）': '2346', '很滿意（%）': '22.4', '滿意（%）': '48.8', '普通（%）': '25.8', '不滿意（%）': '2.6', '很不滿意（%）': '0.3'}), ('碩士及以上', {'樣本數（人）': '440', '很滿意（%）': '21.7', '滿意（%）': '53.4', '普通（%）': '22.4', '不滿意（%）': '1.7', '很不滿意（%）': '0.8'})]

# %% [markdown]
# ### 定義marital()函數，儲存婚姻狀況內容

# %%
def marital(dict_categories): 
    number = len(dict_categories['婚姻狀況']) 
    #len()函式用來計算dict婚姻狀況共有幾個key
    content = []
    for i in dict_categories['婚姻狀況']: #for detail in dict_categories['婚姻狀況'].items:
        detail = (i,dict_categories['婚姻狀況'][i]) #用 .items 這行就可以不用
        content.append(detail)
    return number, content

# %%
for n in data.items():
    a, b = marital(n[1])
    print(a)
    print(b)
# Out:
# 4
# [('未婚', {'樣本數（人）': '1642', '很滿意（%）': '22.2', '滿意（%）': '46.3', '普通（%）': '28.5', '不滿意（%）': '2.6', '很不滿意（%）': '0.3'}), ('有配偶(或同居)', {'樣本數（人）': '2228', '很滿意（%）': '24.3', '滿意（%）': '51', '普通（%）': '22.6', '不滿意（%）': '1.7', '很不滿意（%）': '0.3'}), ('離婚或分居', {'樣本數（人）': '197', '很滿意（%）': '29.3', '滿意（%）': '47.1', '普通（%）': '19.7', '不滿意（%）': '2.2', '很不滿意（%）': '1.7'}), ('喪偶', {'樣本數（人）': '63', '很滿意（%）': '22.6', '滿意（%）': '47.8', '普通（%）': '29.6', '不滿意（%）': '-', '很不滿意（%）': '-'})]

# %% [markdown]
# ### 定義profession()函數，儲存職業內容

# %%
def profession(dict_categories): 
    number = len(dict_categories['職業']) 
    #len()函式用來計算dict職業共有幾個key
    content = []
    for i in dict_categories['職業']: #for detail in dict_categories['職業'].items:
        detail = (i,dict_categories['職業'][i]) #用 .items 這行就可以不用
        content.append(detail)
    return number, content

# %%
for n in data.items():
    a, b = profession(n[1])
    print(a)
    print(b)
# Out:
# 9
# ...

# %% [markdown]
# ### 定義area()函數，儲存地區內容

# %%
def area(dict_categories): 
    number = len(dict_categories['地區']) 
    #len()函式用來計算dict地區共有幾個key
    content = []
    for i in dict_categories['地區']: #for detail in dict_categories['地區'].items:
        detail = (i,dict_categories['地區'][i]) #用 .items 這行就可以不用
        content.append(detail)
    return number, content

# %%
for n in data.items():
    a, b = area(n[1])
    print(a)
    print(b)
# Out:
# 4
# [('北部地區', {'樣本數（人）': '2011', '很滿意（%）': '23.4', '滿意（%）': '48.1', '普通（%）': '25.4', '不滿意（%）': '2.5', '很不滿意（%）': '0.5'}), ('中部地區', {'樣本數（人）': '932', '很滿意（%）': '25.9', '滿意（%）': '49', '普通（%）': '23.4', '不滿意（%）': '1.4', '很不滿意（%）': '0.3'}), ('南部地區', {'樣本數（人）': '838', '很滿意（%）': '22', '滿意（%）': '50.6', '普通（%）': '25.5', '不滿意（%）': '1.7', '很不滿意（%）': '0.2'}), ('東部地區', {'樣本數（人）': '349', '很滿意（%）': '25.2', '滿意（%）': '55.1', '普通（%）': '19.2', '不滿意（%）': '0.4', '很不滿意（%）': '0.1'})]

# %% [markdown]
# ### 定義industry()函數，儲存行業內容

# %%
def industry(dict_categories): 
    number = len(dict_categories['行業']) 
    #len()函式用來計算dict行業共有幾個key
    content = []
    for i in dict_categories['行業']: #for detail in dict_categories['行業'].items:
        detail = (i,dict_categories['行業'][i]) #用 .items 這行就可以不用
        content.append(detail)
    return number, content

# %%
for n in data.items():
    a, b = industry(n[1])
    print(a)
    print(b)
# Out:
# 21
# ...

# %%
def s1(dict_percentage): 
    number = len(dict_percentage['for n in data.items():
    a, b = industry(n[1])
    print(a)
    print(b)']) 
    #len()函式用來計算dict行業共有幾個key
    content = []
    for i in dict_percentage['很滿意（%）']: #for detail in dict_categories['行業'].items:
        detail = (i,dict_percentage['很滿意（%）'][i]) #用 .items 這行就可以不用
        content.append(detail)
    return number, content

# %%
for n in data.items():
    a, b = s1(n[1])
    print(a)
    print(b)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [111], in <cell line: 1>()
#       1 for n in data.items():
# ----> 2     a, b = s1(n[1])
#       3     print(a)
#       4     print(b)
#
# Input In [109], in s1(dict_percentage)
#       1 def s1(dict_percentage):
# ----> 2     number = len(dict_percentage[''])
#       3     #len()函式用來計算dict行業共有幾個key
#       4     content = []
#
# KeyError: ''

# %%
for n in data.items():
    for m in industry():
        satisfication1 = '很滿意（%）'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [77], in <cell line: 1>()
#       1 for n in data.items():
# ----> 2     for m in industry():
#       3         satisfication1 = '很滿意（%）'
#
# TypeError: industry() missing 1 required positional argument: 'dict_滿意度調查'

# %%
#定義滿意度(很滿意（%）)
def satisfication1(dict_滿意度調查):
    content = []
    for i in dict_滿意度調查['很滿意（%）']: #for key, value in dict_name['罰鍰'].items:
        percentage = (i,dict_滿意度調查['很滿意（%）'][i])
        content.append(percentage)
    return content

# %%
for n in data.items():
    n = satisfication1(n[1])
    print(a)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [74], in <cell line: 1>()
#       1 for n in data.items():
# ----> 2     a = satisfication1(n[1])
#       3     print(a)
#
# Input In [70], in satisfication1(dict_滿意度調查)
#       2 def satisfication1(dict_滿意度調查):
#       3     content = []
# ----> 4     for i in dict_滿意度調查['很滿意（%）']: #for key, value in dict_name['罰鍰'].items:
#       5         percentage = (i,dict_滿意度調查['很滿意（%）'][i])
#       6         content.append(percentage)
#
# KeyError: '很滿意（%）'

# %%
dict_滿意度調查
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [67], in <cell line: 1>()
# ----> 1 dict_滿意度調查
#
# NameError: name 'dict_滿意度調查' is not defined

# %%
s = input("輸入項目別:")
# Out:
# 輸入項目別:地區
